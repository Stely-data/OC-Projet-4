# %% [markdown]
# <b><font color="SteelBlue" size="+3">Anticipez les besoins en consommation de bâtiments 2</font></b>

# %% [markdown]
# Ce notebook est la suite du notebook d'exploration des données Deveau_Estelle_1_notebook_exploratoire_022024

# %% [markdown]
# # Introduction

# %% [markdown]
# ## Imports

# %%
# Chargement des librairies
# Builtin
import os

# Data
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# ML
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.linear_model import LinearRegression
import time
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score

# hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Data

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data',
#  'Deveau_Estelle_1_notebook_exploratoire_022024.ipynb',
#  'Deveau_Estelle_2_notebook_prediction_022024.ipynb',
#  'Map_of_Seattle,_divided_by_districts.png',
#  'svg']

# %%
os.listdir("data/cleaned/")
# Out:
# ['df_cleaned.csv']

# %%
path     = "./data/cleaned/"
filename = "df_cleaned.csv"

# %%
df = pd.read_csv(path + filename)
df.head()
# Out:
#    TotalGHGEmissions  SiteEnergyUseWN(kBtu)  Log_TotalGHGEmissions  \
# 0             249.98              7456910.0               5.521381
# 1             295.86              8664479.0               5.689886
# 2            2089.28             73937112.0               7.644575
# 3             286.43              6946800.5               5.657494
# 4             176.14              6062767.5               5.171279
#
#    Log_SiteEnergyUseWN  NumberofBuildings  NumberofFloors    BuildingType  \
# 0            15.824652                1.0              12  NonResidential
# 1            15.974742                1.0              11  NonResidential
# 2            18.118725                1.0              41  NonResidential
# 3            15.753792                1.0              10  NonResidential
# 4            15.617677                1.0              11  NonResidential
#
#    NumberOfPropertyUseTypes  PropertyGFATotal  LargestPropertyUseTypeGFA_pct  \
# 0                         1             88434                     100.000000
# 1                         3            103566                      80.991831
# 2                         1            956110                      79.362597
# 3                         1             61320                     100.000000
# 4                         1             83008                     100.000000
#
#    ...  PropertyGFAParking_pct  BuildingAge    GroupedNeighborhood  \
# 0  ...                0.000000           89  commercial_industrial
# 1  ...               14.545314           20  commercial_industrial
# 2  ...               20.637403           47  commercial_industrial
# 3  ...                0.000000           90  commercial_industrial
# 4  ...                0.000000           90  commercial_industrial
#
#    GroupedLargType       GroupedSecondLargType GroupedThirdLargType  \
# 0   D - Résidences           X - Non classifie    X - Non classifie
# 1   D - Résidences  C - Commerce resto loisirs    X - Non classifie
# 2   D - Résidences           X - Non classifie    X - Non classifie
# 3   D - Résidences           X - Non classifie    X - Non classifie
# 4   D - Résidences           X - Non classifie    X - Non classifie
#
#   SteamUse_pct Electricity_pct  NaturalGas_pct  ENERGYSTARScore
# 0    26.872820       52.917723       17.117720             60.0
# 1     0.000000       37.426959       59.381320             61.0
# 2    29.168781       66.984851        2.020366             43.0
# 3    31.877211       39.858983       26.072621             56.0
# 4     0.000000       46.368511       48.617731             27.0
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1109 entries, 0 to 1108
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   TotalGHGEmissions                    1109 non-null   float64
#  1   SiteEnergyUseWN(kBtu)                1109 non-null   float64
#  2   Log_TotalGHGEmissions                1109 non-null   float64
#  3   Log_SiteEnergyUseWN                  1109 non-null   float64
#  4   NumberofBuildings                    1109 non-null   float64
#  5   NumberofFloors                       1109 non-null   int64
#  6   BuildingType                         1109 non-null   object
#  7   NumberOfPropertyUseTypes             1109 non-null   int64
#  8   PropertyGFATotal                     1109 non-null   int64
#  9   LargestPropertyUseTypeGFA_pct        1109 non-null   float64
#  10  SecondLargestPropertyUseTypeGFA_pct  1109 non-null   float64
#  11  ThirdLargestPropertyUseTypeGFA_pct   1109 non-null   float64
#  12  PropertyGFAParking_pct               1109 non-null   float64
#  13  BuildingAge                          1109 non-null   int64
#  14  GroupedNeighborhood                  1109 non-null   object
#  15  GroupedLargType                      1109 non-null   object
#  16  GroupedSecondLargType                1109 non-null   object
#  17  GroupedThirdLargType                 1109 non-null   object
#  18  SteamUse_pct                         1109 non-null   float64
#  19  Electricity_pct                      1109 non-null   float64
#  20  NaturalGas_pct                       1109 non-null   float64
#  21  ENERGYSTARScore                      701 non-null    float64
# dtypes: float64(13), int64(4), object(5)
# memory usage: 190.7+ KB

# %%
df.describe()
# Out:
#        TotalGHGEmissions  SiteEnergyUseWN(kBtu)  Log_TotalGHGEmissions  \
# count        1109.000000           1.109000e+03            1109.000000
# mean          169.832362           8.178016e+06               3.877767
# std           644.438367           3.223506e+07               1.515763
# min             0.400000           5.811420e+04              -0.916291
# 25%            18.810000           1.186733e+06               2.934389
# 50%            46.450000           2.394062e+06               3.838376
# 75%           132.710000           6.211750e+06               4.888166
# max         12307.160000           8.739237e+08               9.417936
#
#        Log_SiteEnergyUseWN  NumberofBuildings  NumberofFloors  \
# count          1109.000000        1109.000000     1109.000000
# mean             14.856429           1.253381        4.032462
# std               1.291348           3.555618        6.829858
# min              10.970165           1.000000        1.000000
# 25%              13.986715           1.000000        1.000000
# 50%              14.688502           1.000000        2.000000
# 75%              15.641953           1.000000        4.000000
# max              20.588504         111.000000       76.000000
#
#        NumberOfPropertyUseTypes  PropertyGFATotal  \
# count               1109.000000      1.109000e+03
# mean                   1.833183      1.109784e+05
# std                    1.182048      3.417603e+05
# min                    1.000000      1.128500e+04
# 25%                    1.000000      2.708500e+04
# 50%                    1.000000      4.339000e+04
# 75%                    2.000000      8.726200e+04
# max                   11.000000      9.320156e+06
#
#        LargestPropertyUseTypeGFA_pct  SecondLargestPropertyUseTypeGFA_pct  \
# count                    1109.000000                          1109.000000
# mean                       88.746042                             8.113658
# std                        16.889800                            13.748904
# min                        33.333333                             0.000000
# 25%                        80.896925                             0.000000
# 50%                       100.000000                             0.000000
# 75%                       100.000000                            12.663707
# max                       100.000000                            50.000000
#
#        ThirdLargestPropertyUseTypeGFA_pct  PropertyGFAParking_pct  \
# count                         1109.000000             1109.000000
# mean                             1.502393                1.637907
# std                              4.954547                5.154676
# min                              0.000000                0.000000
# 25%                              0.000000                0.000000
# 50%                              0.000000                0.000000
# 75%                              0.000000                0.000000
# max                             33.333333               27.637240
#
#        BuildingAge  SteamUse_pct  Electricity_pct  NaturalGas_pct  \
# count  1109.000000   1109.000000      1109.000000     1109.000000
# mean     58.504959      2.057110        65.397990       27.272598
# std      31.555596      8.655708        27.444465       24.483969
# min       1.000000      0.000000         0.000000        0.000000
# 25%      35.000000      0.000000        43.086418        0.000000
# 50%      55.000000      0.000000        64.341640       26.074393
# 75%      88.000000      0.000000        94.824479       47.645524
# max     116.000000     64.773098       103.872233      100.000000
#
#        ENERGYSTARScore
# count       701.000000
# mean         63.078459
# std          28.737250
# min           1.000000
# 25%          43.000000
# 50%          70.000000
# 75%          88.000000
# max         100.000000

# %% [markdown]
# Nous allons commencer par chercher un modèle de ML pour prédire le SiteEnergyUseWN

# %% [markdown]
# Dans un premier temps, nous allons travailler en excluant l'ENERGYSTARScore puis nous ferons une comparaison avec son utilisation.

# %% [markdown]
# # Modelisation sans l'Energy Star Score

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Séparation des données

# %%
# Sélection des variables explicatives et des variables cibles
features = df.drop(['Log_TotalGHGEmissions', 'Log_SiteEnergyUseWN', 'TotalGHGEmissions', 'SiteEnergyUseWN(kBtu)', 'ENERGYSTARScore'], axis=1)
target = df['Log_SiteEnergyUseWN']

# Transformation des variables catégorielles en variables numériques (encodage one-hot)
features = pd.get_dummies(features)

# Séparation des données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)
# Conservez les noms des colonnes dans une variable avant la mise à l'échelle
column_names = X_train.columns

# Affichage des dimensions des ensembles d'entraînement et de test
X_train.shape, X_test.shape
# Out:
# ((887, 43), (222, 43))

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 887 entries, 616 to 860
# Data columns (total 43 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   NumberofBuildings                                 887 non-null    float64
#  1   NumberofFloors                                    887 non-null    int64
#  2   NumberOfPropertyUseTypes                          887 non-null    int64
#  3   PropertyGFATotal                                  887 non-null    int64
#  4   LargestPropertyUseTypeGFA_pct                     887 non-null    float64
#  5   SecondLargestPropertyUseTypeGFA_pct               887 non-null    float64
#  6   ThirdLargestPropertyUseTypeGFA_pct                887 non-null    float64
#  7   PropertyGFAParking_pct                            887 non-null    float64
#  8   BuildingAge                                       887 non-null    int64
#  9   SteamUse_pct                                      887 non-null    float64
#  10  Electricity_pct                                   887 non-null    float64
#  11  NaturalGas_pct                                    887 non-null    float64
#  12  BuildingType_Campus                               887 non-null    bool
#  13  BuildingType_NonResidential                       887 non-null    bool
#  14  BuildingType_Nonresidential COS                   887 non-null    bool
#  15  BuildingType_Nonresidential WA                    887 non-null    bool
#  16  BuildingType_SPS-District K-12                    887 non-null    bool
#  17  GroupedNeighborhood_commercial_industrial         887 non-null    bool
#  18  GroupedNeighborhood_residential                   887 non-null    bool
#  19  GroupedNeighborhood_urban_core                    887 non-null    bool
#  20  GroupedLargType_A - Data Center Sante             887 non-null    bool
#  21  GroupedLargType_B - Public et culturel            887 non-null    bool
#  22  GroupedLargType_C - Commerce resto loisirs        887 non-null    bool
#  23  GroupedLargType_D - Résidences                    887 non-null    bool
#  24  GroupedLargType_E - Industrie et entrepots        887 non-null    bool
#  25  GroupedLargType_F - Bureaux et services           887 non-null    bool
#  26  GroupedLargType_G - Autres                        887 non-null    bool
#  27  GroupedSecondLargType_A - Data Center Sante       887 non-null    bool
#  28  GroupedSecondLargType_B - Public et culturel      887 non-null    bool
#  29  GroupedSecondLargType_C - Commerce resto loisirs  887 non-null    bool
#  30  GroupedSecondLargType_D - Résidences              887 non-null    bool
#  31  GroupedSecondLargType_E - Industrie et entrepots  887 non-null    bool
#  32  GroupedSecondLargType_F - Bureaux et services     887 non-null    bool
#  33  GroupedSecondLargType_G - Autres                  887 non-null    bool
#  34  GroupedSecondLargType_X - Non classifie           887 non-null    bool
#  35  GroupedThirdLargType_A - Data Center Sante        887 non-null    bool
#  36  GroupedThirdLargType_B - Public et culturel       887 non-null    bool
#  37  GroupedThirdLargType_C - Commerce resto loisirs   887 non-null    bool
#  38  GroupedThirdLargType_D - Résidences               887 non-null    bool
#  39  GroupedThirdLargType_E - Industrie et entrepots   887 non-null    bool
#  40  GroupedThirdLargType_F - Bureaux et services      887 non-null    bool
#  41  GroupedThirdLargType_G - Autres                   887 non-null    bool
#  42  GroupedThirdLargType_X - Non classifie            887 non-null    bool
# dtypes: bool(31), float64(8), int64(4)
# memory usage: 116.9 KB

# %%
X_train.head()
# Out:
#      NumberofBuildings  NumberofFloors  NumberOfPropertyUseTypes  \
# 616                1.0               1                         2
# 990                1.0               1                         3
# 706                1.0               2                         3
# 777                1.0               1                         1
# 732                1.0               1                         1
#
#      PropertyGFATotal  LargestPropertyUseTypeGFA_pct  \
# 616             21101                      87.071703
# 990             35017                      65.908258
# 706             20088                      82.124617
# 777             25880                     100.000000
# 732             23706                     100.000000
#
#      SecondLargestPropertyUseTypeGFA_pct  ThirdLargestPropertyUseTypeGFA_pct  \
# 616                            12.928297                                 0.0
# 990                            34.091742                                 0.0
# 706                            17.875383                                 0.0
# 777                             0.000000                                 0.0
# 732                             0.000000                                 0.0
#
#      PropertyGFAParking_pct  BuildingAge  SteamUse_pct  ...  \
# 616                     0.0           27           0.0  ...
# 990                     0.0           47           0.0  ...
# 706                     0.0           37           0.0  ...
# 777                     0.0           72           0.0  ...
# 732                     0.0           53           0.0  ...
#
#      GroupedSecondLargType_G - Autres  \
# 616                             False
# 990                             False
# 706                             False
# 777                             False
# 732                             False
#
#      GroupedSecondLargType_X - Non classifie  \
# 616                                    False
# 990                                    False
# 706                                    False
# 777                                     True
# 732                                     True
#
#      GroupedThirdLargType_A - Data Center Sante  \
# 616                                       False
# 990                                       False
# 706                                       False
# 777                                       False
# 732                                       False
#
#      GroupedThirdLargType_B - Public et culturel  \
# 616                                        False
# 990                                        False
# 706                                        False
# 777                                        False
# 732                                        False
#
#      GroupedThirdLargType_C - Commerce resto loisirs  \
# 616                                            False
# 990                                            False
# 706                                            False
# 777                                            False
# 732                                            False
#
#      GroupedThirdLargType_D - Résidences  \
# 616                                False
# 990                                False
# 706                                False
# 777                                False
# 732                                False
#
#      GroupedThirdLargType_E - Industrie et entrepots  \
# 616                                            False
# 990                                            False
# 706                                            False
# 777                                            False
# 732                                            False
#
#      GroupedThirdLargType_F - Bureaux et services  \
# 616                                         False
# 990                                         False
# 706                                         False
# 777                                         False
# 732                                         False
#
#      GroupedThirdLargType_G - Autres  GroupedThirdLargType_X - Non classifie
# 616                            False                                    True
# 990                            False                                    True
# 706                            False                                    True
# 777                            False                                    True
# 732                            False                                    True
#
# [5 rows x 43 columns]

# %%
y_train.head()
# Out:
# 616    13.616441
# 990    14.147898
# 706    12.729428
# 777    12.001260
# 732    13.031307
# Name: Log_SiteEnergyUseWN, dtype: float64

# %% [markdown]
# ### Standardisation

# %%
# Initialisation du StandardScaler
scaler = StandardScaler()

# %%
columns_to_scale=['NumberofBuildings','NumberofFloors',	'NumberOfPropertyUseTypes', 'PropertyGFATotal', 'LargestPropertyUseTypeGFA_pct', 
                  'SecondLargestPropertyUseTypeGFA_pct', 'ThirdLargestPropertyUseTypeGFA_pct',
                  'BuildingAge', 'SteamUse_pct', 'Electricity_pct', 'NaturalGas_pct']

# %%
# Séparer les colonnes à normaliser
X_train_to_scale = X_train[columns_to_scale]
X_test_to_scale = X_test[columns_to_scale]

# Appliquer la normalisation sur ces colonnes
X_train_scaled = scaler.fit_transform(X_train_to_scale)
X_test_scaled = scaler.transform(X_test_to_scale)

# Merge
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=columns_to_scale, index=X_train.index)
X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=columns_to_scale, index=X_test.index)
X_train_final = X_train.drop(columns=columns_to_scale).join(X_train_scaled_df)
X_test_final = X_test.drop(columns=columns_to_scale).join(X_test_scaled_df)

# %%
X_train_final.head()
# Out:
#      PropertyGFAParking_pct  BuildingType_Campus  BuildingType_NonResidential  \
# 616                     0.0                False                         True
# 990                     0.0                False                         True
# 706                     0.0                False                         True
# 777                     0.0                False                         True
# 732                     0.0                False                         True
#
#      BuildingType_Nonresidential COS  BuildingType_Nonresidential WA  \
# 616                            False                           False
# 990                            False                           False
# 706                            False                           False
# 777                            False                           False
# 732                            False                           False
#
#      BuildingType_SPS-District K-12  \
# 616                           False
# 990                           False
# 706                           False
# 777                           False
# 732                           False
#
#      GroupedNeighborhood_commercial_industrial  \
# 616                                       True
# 990                                       True
# 706                                      False
# 777                                       True
# 732                                       True
#
#      GroupedNeighborhood_residential  GroupedNeighborhood_urban_core  \
# 616                            False                           False
# 990                            False                           False
# 706                            False                            True
# 777                            False                           False
# 732                            False                           False
#
#      GroupedLargType_A - Data Center Sante  ...  NumberofFloors  \
# 616                                  False  ...       -0.456079
# 990                                  False  ...       -0.456079
# 706                                  False  ...       -0.293351
# 777                                  False  ...       -0.456079
# 732                                  False  ...       -0.456079
#
#      NumberOfPropertyUseTypes  PropertyGFATotal  \
# 616                  0.151962         -0.239709
# 990                  1.038743         -0.201472
# 706                  1.038743         -0.242493
# 777                 -0.734819         -0.226578
# 732                 -0.734819         -0.232552
#
#      LargestPropertyUseTypeGFA_pct  SecondLargestPropertyUseTypeGFA_pct  \
# 616                      -0.095229                             0.335021
# 990                      -1.339196                             1.859290
# 706                      -0.386014                             0.691329
# 777                       0.664684                            -0.596122
# 732                       0.664684                            -0.596122
#
#      ThirdLargestPropertyUseTypeGFA_pct  BuildingAge  SteamUse_pct  \
# 616                           -0.303915    -1.001254     -0.252329
# 990                           -0.303915    -0.358114     -0.252329
# 706                           -0.303915    -0.679684     -0.252329
# 777                           -0.303915     0.445812     -0.252329
# 732                           -0.303915    -0.165172     -0.252329
#
#      Electricity_pct  NaturalGas_pct
# 616        -1.603876        1.385963
# 990        -0.014706        0.036287
# 706         1.140506       -1.093915
# 777         1.255812       -1.093915
# 732        -0.960203        0.883643
#
# [5 rows x 43 columns]

# %% [markdown]
# ## Préparation des métriques

# %%
# Fonction pour calculer les métriques
def calc_metrics(y_true, y_pred):
    # Calcul du RMSE 
    rmse_log = np.sqrt(mean_squared_error(y_true, y_pred))
    
    # Calcul du R-squared 
    r2_log = r2_score(y_true, y_pred)
    
    # Calcul du MAE 
    mae_log = mean_absolute_error(y_true, y_pred)
    
    return rmse_log, r2_log, mae_log

# Fonction pour afficher les métriques
def display_metrics(rmse_log, r2_log, mae_log):
    # Affichage des métriques
    print(f"RMSE : {rmse_log}")
    print(f"R-squared : {r2_log}")
    print(f"MAE : {mae_log}")

# %% [markdown]
# ## Tests de modèles

# %% [markdown]
# ### Régression linéaire (Baseline)

# %%
# Création et entraînement du modèle de régression linéaire
model = LinearRegression()
model.fit(X_train_final, y_train)

# Prédiction sur le jeu de test
y_pred = model.predict(X_test_final)

print("Métriques pour le modèle moyen :")
metrics = calc_metrics(y_test, y_pred)
display_metrics(*metrics)
# Out:
# Métriques pour le modèle moyen :
# RMSE : 0.8538478806267107
# R-squared : 0.5397517051759972
# MAE : 0.6610802774238035

# %% [markdown]
# ### SVR

# %%
# Démarre le chronomètre
start_time = time.time()

# Création du modèle SVM pour la régression
svr_model = SVR()

# Entraînement du modèle sur les données d'entraînement
svr_model.fit(X_train_final, y_train)

# Prédiction sur le jeu de test
y_pred_svr = svr_model.predict(X_test_final)

# Arrête le chronomètre
end_time = time.time()

# Calcule la durée totale
duration = end_time - start_time

print(f"Le temps de calcul est de {duration:.2f} secondes")
print("Métriques pour Support Vector Regression:")
metrics = calc_metrics(y_test, y_pred_svr)
display_metrics(*metrics)
# Out:
# Le temps de calcul est de 0.05 secondes
# Métriques pour Support Vector Regression:
# RMSE : 0.7765837292965461
# R-squared : 0.6192781931861666
# MAE : 0.5999941176455289

# %% [markdown]
# ### Forêt aléatoire

# %%
# Démarre le chronomètre
start_time = time.time()

# Création du modèle Random Forest
rf_model = RandomForestRegressor()

# Entraînement du modèle sur les données d'entraînement
rf_model.fit(X_train_final, y_train)

# Prédiction sur le jeu de test
y_pred_rf = rf_model.predict(X_test_final)

# Arrête le chronomètre
end_time = time.time()

# Calcule la durée totale
duration = end_time - start_time

print(f"Le temps de calcul est de {duration:.2f} secondes")
print("Métriques pour Random Forest:")
metrics = calc_metrics(y_test, y_pred_rf)
display_metrics(*metrics)
# Out:
# Le temps de calcul est de 0.76 secondes
# Métriques pour Random Forest:
# RMSE : 0.5679746070372373
# R-squared : 0.7963478412295011
# MAE : 0.430724785285163

# %%
importances_rf = rf_model.feature_importances_

# Création d'un DataFrame pour afficher l'importance des variables
features_rf = pd.DataFrame({'Feature': X_train.columns, 'Importance': importances_rf})
features_rf = features_rf.sort_values(by='Importance', ascending=False)

print(features_rf)
# Out:
#                                              Feature  Importance
# 35        GroupedThirdLargType_A - Data Center Sante    0.647968
# 13                       BuildingType_NonResidential    0.055358
# 39   GroupedThirdLargType_E - Industrie et entrepots    0.052910
# 41                   GroupedThirdLargType_G - Autres    0.050120
# 42            GroupedThirdLargType_X - Non classifie    0.049823
# 9                                       SteamUse_pct    0.019772
# 11                                    NaturalGas_pct    0.019603
# 33                  GroupedSecondLargType_G - Autres    0.016344
# 36       GroupedThirdLargType_B - Public et culturel    0.011965
# 37   GroupedThirdLargType_C - Commerce resto loisirs    0.010841
# 34           GroupedSecondLargType_X - Non classifie    0.010749
# 14                   BuildingType_Nonresidential COS    0.005442
# 6                 ThirdLargestPropertyUseTypeGFA_pct    0.004153
# 8                                        BuildingAge    0.003592
# 15                    BuildingType_Nonresidential WA    0.003303
# 7                             PropertyGFAParking_pct    0.003301
# 40      GroupedThirdLargType_F - Bureaux et services    0.003222
# 21            GroupedLargType_B - Public et culturel    0.003104
# 10                                   Electricity_pct    0.003030
# 0                                  NumberofBuildings    0.002659
# 38               GroupedThirdLargType_D - Résidences    0.002546
# 5                SecondLargestPropertyUseTypeGFA_pct    0.002377
# 32     GroupedSecondLargType_F - Bureaux et services    0.002116
# 3                                   PropertyGFATotal    0.001964
# 12                               BuildingType_Campus    0.001912
# 18                   GroupedNeighborhood_residential    0.001887
# 2                           NumberOfPropertyUseTypes    0.001823
# 23                    GroupedLargType_D - Résidences    0.001277
# 29  GroupedSecondLargType_C - Commerce resto loisirs    0.001174
# 20             GroupedLargType_A - Data Center Sante    0.001121
# 22        GroupedLargType_C - Commerce resto loisirs    0.000931
# 26                        GroupedLargType_G - Autres    0.000727
# 31  GroupedSecondLargType_E - Industrie et entrepots    0.000680
# 1                                     NumberofFloors    0.000511
# 28      GroupedSecondLargType_B - Public et culturel    0.000360
# 16                    BuildingType_SPS-District K-12    0.000343
# 17         GroupedNeighborhood_commercial_industrial    0.000276
# 30              GroupedSecondLargType_D - Résidences    0.000252
# 19                    GroupedNeighborhood_urban_core    0.000213
# 25           GroupedLargType_F - Bureaux et services    0.000149
# 24        GroupedLargType_E - Industrie et entrepots    0.000091
# 27       GroupedSecondLargType_A - Data Center Sante    0.000009
# 4                      LargestPropertyUseTypeGFA_pct    0.000004

# %% [markdown]
# ### Gradient Boosting

# %%
# Démarre le chronomètre
start_time = time.time()

# Création du modèle Gradient Boosting
gb_model = GradientBoostingRegressor()

# Entraînement du modèle sur les données d'entraînement
gb_model.fit(X_train_final, y_train)

# Prédiction sur le jeu de test
y_pred_gb = gb_model.predict(X_test_final)

# Arrête le chronomètre
end_time = time.time()

# Calcule la durée totale
duration = end_time - start_time

print(f"Le temps de calcul est de {duration:.2f} secondes")
print("Métriques pour Gradient Boosting:")
metrics = calc_metrics(y_test, y_pred_gb)
display_metrics(*metrics)
# Out:
# Le temps de calcul est de 0.22 secondes
# Métriques pour Gradient Boosting:
# RMSE : 0.6062381037854625
# R-squared : 0.7679841589542076
# MAE : 0.45974255489635524

# %%
importances_gb = gb_model.feature_importances_

# Création d'un DataFrame pour afficher l'importance des variables
features_gb = pd.DataFrame({'Feature': X_train.columns, 'Importance': importances_gb})
features_gb = features_gb.sort_values(by='Importance', ascending=False)

print(features_gb)
# Out:
#                                              Feature  Importance
# 35        GroupedThirdLargType_A - Data Center Sante    0.715670
# 13                       BuildingType_NonResidential    0.072360
# 42            GroupedThirdLargType_X - Non classifie    0.043345
# 41                   GroupedThirdLargType_G - Autres    0.035436
# 9                                       SteamUse_pct    0.030901
# 11                                    NaturalGas_pct    0.022041
# 39   GroupedThirdLargType_E - Industrie et entrepots    0.020377
# 34           GroupedSecondLargType_X - Non classifie    0.007145
# 36       GroupedThirdLargType_B - Public et culturel    0.006246
# 37   GroupedThirdLargType_C - Commerce resto loisirs    0.005729
# 5                SecondLargestPropertyUseTypeGFA_pct    0.004831
# 32     GroupedSecondLargType_F - Bureaux et services    0.004439
# 14                   BuildingType_Nonresidential COS    0.004319
# 15                    BuildingType_Nonresidential WA    0.003740
# 33                  GroupedSecondLargType_G - Autres    0.003338
# 40      GroupedThirdLargType_F - Bureaux et services    0.003274
# 1                                     NumberofFloors    0.002375
# 12                               BuildingType_Campus    0.001901
# 38               GroupedThirdLargType_D - Résidences    0.001789
# 3                                   PropertyGFATotal    0.001650
# 0                                  NumberofBuildings    0.001555
# 20             GroupedLargType_A - Data Center Sante    0.001322
# 2                           NumberOfPropertyUseTypes    0.001255
# 25           GroupedLargType_F - Bureaux et services    0.001203
# 18                   GroupedNeighborhood_residential    0.001010
# 10                                   Electricity_pct    0.000596
# 6                 ThirdLargestPropertyUseTypeGFA_pct    0.000493
# 8                                        BuildingAge    0.000491
# 17         GroupedNeighborhood_commercial_industrial    0.000422
# 7                             PropertyGFAParking_pct    0.000258
# 21            GroupedLargType_B - Public et culturel    0.000201
# 24        GroupedLargType_E - Industrie et entrepots    0.000146
# 16                    BuildingType_SPS-District K-12    0.000088
# 28      GroupedSecondLargType_B - Public et culturel    0.000055
# 31  GroupedSecondLargType_E - Industrie et entrepots    0.000000
# 22        GroupedLargType_C - Commerce resto loisirs    0.000000
# 30              GroupedSecondLargType_D - Résidences    0.000000
# 29  GroupedSecondLargType_C - Commerce resto loisirs    0.000000
# 27       GroupedSecondLargType_A - Data Center Sante    0.000000
# 26                        GroupedLargType_G - Autres    0.000000
# 4                      LargestPropertyUseTypeGFA_pct    0.000000
# 23                    GroupedLargType_D - Résidences    0.000000
# 19                    GroupedNeighborhood_urban_core    0.000000

# %% [markdown]
# <b>Modèle Baseline</b> : <br>
# Le modèle de régréssion linéaire sert de point de référence minimal pour évaluer les performances des autres modèles.
#
# <b>Forêt Aléatoire</b> :<br>
# Le modèle de forêt aléatoire a surpassé de manière significative la régression linéaire, avec un RMSE plus faible et un R-squared positif.
#
# <b>Gradient Boosting</b> :<br>
# Le modèle Gradient Boosting offre une amélioration légère mais significative sur la forêt aléatoire en termes de RMSE et de R-squared.
# Le Gradient Boosting est également plus rapide à calculer.
#
# <b>Résumé</b> :
#    - Le modèle moyen sert d'étalon de base, mais ses performances sont clairement surpassées par des modèles plus complexes.
#    - La forêt aléatoire et le Gradient Boosting émergent comme les meilleurs candidats pour résoudre ce problème, avec un  avantage pour le gradient boosting.
#
#
# Compte tenu de ces résultats, nous allons procéder à une validation croisée des modèles de Gradient Boosting et Random Forest pour confirmer le meilleur modèle.

# %% [markdown]
# ## Validation croisée

# %%
# Métriques à utiliser
scoring = ['neg_mean_squared_error', 'r2', 'neg_mean_absolute_error']

# Pour Random Forest
rf_scores = cross_validate(rf_model, X_train_final, y_train, cv=5, scoring=scoring)
rf_rmse = np.sqrt(-rf_scores['test_neg_mean_squared_error'].mean())
rf_r2 = rf_scores['test_r2'].mean()
rf_mae = -rf_scores['test_neg_mean_absolute_error'].mean()

# Pour Gradient Boosting
gb_scores = cross_validate(gb_model, X_train_final, y_train, cv=5, scoring=scoring)
gb_rmse = np.sqrt(-gb_scores['test_neg_mean_squared_error'].mean())
gb_r2 = gb_scores['test_r2'].mean()
gb_mae = -gb_scores['test_neg_mean_absolute_error'].mean()

# Création d'un DataFrame pour afficher les métriques de Random Forest et Gradient Boosting
df_metrics = pd.DataFrame({
    'Metric': ['RMSE', 'R2', 'MAE'],
    'Random Forest': [rf_rmse, rf_r2, rf_mae],
    'Gradient Boosting': [gb_rmse, gb_r2, gb_mae]
})

# Afficher le DataFrame
df_metrics
# Out:
#   Metric  Random Forest  Gradient Boosting
# 0   RMSE       0.696882           0.667543
# 1     R2       0.708116           0.733953
# 2    MAE       0.523893           0.514416

# %% [markdown]
# La différence entre les métriques des deux modèles sont suffisamment significative pour confirmer le choix du Gradient Boosting.

# %% [markdown]
# ## Recherche des hyperparamètres

# %%
# Définition des hyperparamètres à tester
param_dist = {
    'n_estimators': np.arange(50, 300, 10),
    'learning_rate': np.linspace(0.008, 0.2, 20),
    'max_depth': np.arange(2, 10, 1),
    'min_samples_split': np.arange(2, 10, 1),
    'min_samples_leaf': np.arange(1, 5, 1),
    'subsample': np.linspace(0.5, 0.9, 20)
}

# Initialisation de la recherche aléatoire
random_search = RandomizedSearchCV(GradientBoostingRegressor(), param_distributions=param_dist, n_iter=100, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# Exécution de la recherche aléatoire sur le jeu d'entraînement
random_search.fit(X_train_final, y_train)

# Récupération du meilleur modèle
best_gb_model = random_search.best_estimator_

# Affichage des meilleurs hyperparamètres
print(random_search.best_params_)
# Out:
# {'subsample': 0.7105263157894737, 'n_estimators': 120, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_depth': 2, 'learning_rate': 0.1696842105263158}

# %%
# Définition de la grille d'hyperparamètres
param_grid = {
    'learning_rate': [0.03, 0.05, 0.1],
    'max_depth': [2, 3, 4],
    'min_samples_leaf': [2, 3, 4],
    'min_samples_split': [2, 3, 4],
    'n_estimators': [300, 350, 400],
    'subsample': [0.5, 0.6, 0.7]
}

# Configuration de GridSearchCV
grid_search = GridSearchCV(estimator=gb_model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1, verbose=2)

# Exécution de la recherche d'hyperparamètres
grid_search.fit(X_train_final, y_train)

# Affichage des meilleurs paramètres
print("Meilleurs paramètres :", grid_search.best_params_)

# Prédiction avec le meilleur modèle
y_pred = grid_search.best_estimator_.predict(X_test_final)

# Calcul des métriques pour le meilleur modèle
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print("RMSE :", rmse)
print("R² :", r2)
print("MAE :", mae)
# Out:
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# Meilleurs paramètres : {'learning_rate': 0.03, 'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 400, 'subsample': 0.7}
# RMSE : 0.5667130642019439
# R² : 0.7972515105040336
# MAE : 0.43635400090741877

# %%
# Meilleurs hyperparamètres obtenus de GridSearchCV
best_params = grid_search.best_params_

# Configuration du modèle avec les meilleurs hyperparamètres
best_gb_model = GradientBoostingRegressor(
    n_estimators=best_params['n_estimators'],
    learning_rate=best_params['learning_rate'],
    max_depth=best_params['max_depth'],
    min_samples_split=best_params['min_samples_split'],
    min_samples_leaf=best_params['min_samples_leaf'],
    subsample=best_params['subsample'],
    random_state=0
)

# Métriques à évaluer lors de la validation croisée
scoring_metrics = ['neg_mean_squared_error', 'r2', 'neg_mean_absolute_error']

# Exécution de la validation croisée
cv_results = cross_validate(best_gb_model, X_train_final, y_train, cv=5, scoring=scoring_metrics, return_train_score=True)

# Calcul et affichage des métriques moyennes pour chaque pli
rmse_scores = np.sqrt(-cv_results['test_neg_mean_squared_error'])
r2_scores = cv_results['test_r2']
mae_scores = -cv_results['test_neg_mean_absolute_error']

print(f"Validation Croisée RMSE: {rmse_scores.mean():.4f} (± {rmse_scores.std():.4f})")
print(f"Validation Croisée R²: {r2_scores.mean():.4f} (± {r2_scores.std():.4f})")
print(f"Validation Croisée MAE: {mae_scores.mean():.4f} (± {mae_scores.std():.4f})")
# Out:
# Validation Croisée RMSE: 0.6462 (± 0.0407)
# Validation Croisée R²: 0.7495 (± 0.0157)
# Validation Croisée MAE: 0.4946 (± 0.0311)

# %%
best_gb_model.fit(X_train_final, y_train) 

# Prédictions sur l'ensemble d'entraînement
y_train_pred = best_gb_model.predict(X_train_final)

# Prédictions sur l'ensemble de test
y_test_pred = best_gb_model.predict(X_test_final)

# Calcul des métriques pour l'ensemble d'entraînement
train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
train_r2 = r2_score(y_train, y_train_pred)
train_mae = mean_absolute_error(y_train, y_train_pred)

# Calcul des métriques pour l'ensemble de test
test_rmse = np.sqrt(mean_squared_error(y_test, y_test_pred))
test_r2 = r2_score(y_test, y_test_pred)
test_mae = mean_absolute_error(y_test, y_test_pred)

# Affichage des métriques
print("Ensemble d'entraînement : RMSE = {:.4f}, R² = {:.4f}, MAE = {:.4f}".format(train_rmse, train_r2, train_mae))
print("Ensemble de test : RMSE = {:.4f}, R² = {:.4f}, MAE = {:.4f}".format(test_rmse, test_r2, test_mae))
# Out:
# Ensemble d'entraînement : RMSE = 0.3578, R² = 0.9241, MAE = 0.2762
# Ensemble de test : RMSE = 0.5674, R² = 0.7968, MAE = 0.4446
